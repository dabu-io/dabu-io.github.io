# %% [markdown]
# # dabu, una librería de Python enfocada en la BOLSA MEXICANA DE VALORES

# %% [markdown]
# Hoy quiero escribirte sobre la librería `dabu` de Python.  El nombre dabu es la abreviatura de “datos bursátiles” y como su nombre lo indica, está enfocada en facilitar la obtención de *__datos burátiles__* de las emisoras de capitales de la BMV.  La librería es de código abierto, fue desarrollada por el autor de este texto, con el objetivo es facilitar, promover y democratizar el acceso a la información bursátil en nuestro país.
#
# Dabu tiene dos funciones principales:
# 1. Series de precios
#     1. Serie de tiempo con el precio de apertura, máximo, mínimo, cierre y cierre ajustado
#     1. Serie de tiempo intradía, con intervalos de 1, 2, 5, 15, 30, 60 y 90 minutos
# 1. Reportes trimestrales del 2017Q1 a la fecha
#     1. Balance General
#     1. Estado de Resultados
#     1. Estado de Flujos de Efectivo
#
# Para los reportes trimestrales, dabu toma información de los resportes trimestrales publicadas por las emisoras del mercado de capitales de la BMV a través de la Comisión Nacional Bancaria y de Valores.  Las series de precios, los datos se toman directamente de Yahoo! Finance.

# %% [markdown]
# # Nuevo en Python? Sí: Continúa leyendo / No: Avanza al siguiente punto

# %% [markdown]
# Si eres nuevo en Python y quieres instalarlo en tu computadora, te recomiendo que lo instales utilizando el servicio de distribución anaconda (https://www.anaconda.com/products/individual).  Solo tienes que seleccionar tu sistema operativo y la versión gráfica.  Sigue las indicaciones y anaconda instalrá también las librerías más importantes de análisis de datos y machine learning.  Además instalará unas interfaces de usuario, entre ellas Jupyter Notebook y su nueva variante Jupyter Lab.  Estas interfaces de Jupyter junto con las diferentes librerías te pemiten hacer análisis de datos sin la necesidad de saber programar en Python.  Por ejemplo, este documento no tiene programación de Python, lo desarrollé en Jupyter Notebook.  Si yo pude hacerlo, tu también puedes!!!
#
# Si te confundes con los terminos librerías, visualizadores, etc, no estás solo, yo alguna vez fuí también victima de la terminología.  Imagina que Python es un celular inteligente y las librerías son las apps que bajas a tu celular.  Sin las aplicaciones puedes usar el celular pero al momento de instalarlas, vuelves mucho más productivo al celular.  Siguiendo con la misma analogía, Jupyter sería una especie de visualizador de la aplicación para poder interactuar con los datos de la aplicación sin necesidad de recurrir a programar en Python.<br><br>
#
# Cuando me refiera a *__Jupyter__*, *__Jupyter Notebook__* o *__Jupyter Lab__*, me estoy refiriendo a lo mismo.  Para términos prácticos *__Jupyter Lab__* es la evolución de *__Jupyter Notebook__* y puedes hacer lo mismo en uno y el otro.  Una *__libreta de Jupyter__* es un archivo creado en *__Jupyter__* donde correremos Python.

# %% [markdown]
# # Requisitos

# %% [markdown]
# Para usar dabu debes de tener Python 3.6 o mayor, al igual que pandas

# %% [markdown]
# # Explicaciones y detalles de los ejemplos

# %% [markdown]
# Cada función que veremos vendrá acompañada con un preámbulo, opciones de la función, etc.  Enseguida correré la función y de ser necesario describiré que hice y por que.  Esto con el objetivo de facilitar las explicaciones a las personas que no saben Python y puedan seguir los ejemplos sabiendo lo que está sucediendo paso a paso.  De antemano me disculpo con todos ustedes que saben Python y espero que para los nuevos le sea de utilidad.

# %% [markdown]
# # Instalar dabu

# %% [markdown]
# Para instalar dabu, es necesario que correr la siguiente línea desde *terminal* (Mac o Linux), o desde *chmod* (Windows):<br><br>
# ```pip install dabu```

# %% [markdown]
# #### En caso de error
# Si el comdando anterior marca error, es necesario verificar que versión de Python estás utilizando:<br>
# ```python3 --version```<br>
# Si la respuesta es 3.6 o mayor, vuelve a instalar dabu con el siguiente comando:<br>
# ```pip3 install dabu```

# %% [markdown]
# # Usar dabu

# %% [markdown]
# Una vez instalado dabu, es necesario habrír una libreta nueva de Jupytery y seguir los siguientes pasos:

# %% [markdown]
# ## 1.0 Importar dabu a python

# %%
import dabu as db

# %% [markdown]
# > Antes de utilizar las diferentes librerías, las debemos de cargar a Pyhton.

# %% [markdown]
# ## 2.0 Cargar los precios de cierre de Arca

# %% [markdown]
# La clase "*__dabu.Precios__*" pide como argumentos el nombre de pizarra de la emisora (inluyendo la serie, en caso de contar con ella), la fecha inicial y final (en formato 'aaaa-mm-dd').  También podemos poner más de una acción como lo veremos más adelante.<br><br>
# Por lo pronto vamos a pedir los precios para Arca Contal del 1ero de enero del 2018 al 12 de febrero del 2021 y el resultado lo vamos a guardar en una variable que le llamaremos "*__ac__*"

# %%
ac = db.Precios('ac', '2018-01-01', '2022-05-16').resultado

# %% [markdown]
# > * _Al momento de importar dabu en el paso 1.0, le pusimos el sobrenombre "*__db__*", es por eso que ponemos "**db.Precios**"._
# > * _Recordar que el ticker de Arca Contal es "**ac**" y las fechas se dan de alta con el formato "**aaaa-mm-dd**"._
# > * _Tanto "**ac**" como las fechas van entre comillas (muy importante)_
# > * _Por útimo, al finalizar los paréntesis es necesario agregar '**.resultado**'._

# %% [markdown]
# Como podemos ver en la siguiente celda, al aplicarle a la variable **ac** .info, nos arroja como resultado un DataFrame de pandas y con esto podemos trabajar la información directamente en pandas.

# %%
ac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1098 entries, 2018-01-02 to 2022-05-13
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Apertura         1098 non-null   float64
#  1   Máximo           1098 non-null   float64
#  2   Mínimo           1098 non-null   float64
#  3   Cierre           1098 non-null   float64
#  4   Cierre Ajustado  1098 non-null   float64
# dtypes: float64(5)
# memory usage: 51.5 KB

# %% [markdown]
# > _Al aplicar **.info()** a cualquier DataFrame de Pandas, despliega una tabla con el resumen de la misma.  En nuestro caso nos indica que la tabla:_
# > * _Contiene 783 entradas_
# > * _Van desde el 2 de enero del 2018 al 12 de febrero del 2019 y las fechas las considera como DateTime y no como texto_
# > * _Aparte del index (fechas) la table contiene 5 columnas con sus respectivos nombres, el número de datos en cada columna y el tipo de datos_

# %% [markdown]
# Vamos a visualizar los precios de arca que guardamos en la variable **ac**:

# %%
ac
# Out:
#               Apertura      Máximo      Mínimo      Cierre  Cierre Ajustado
# Fecha
# 2018-01-02  136.490005  138.380005  134.119995  138.160004       117.375832
# 2018-01-03  138.990005  138.990005  134.440002  134.699997       114.436333
# 2018-01-04  134.699997  135.289993  133.779999  133.860001       113.722710
# 2018-01-05  133.850006  135.820007  133.830002  134.800003       114.521309
# 2018-01-08  135.000000  136.000000  133.759995  134.910004       114.614769
# ...                ...         ...         ...         ...              ...
# 2022-05-09  128.520004  131.500000  128.360001  128.990005       128.990005
# 2022-05-10  131.470001  133.130005  128.929993  129.199997       129.199997
# 2022-05-11  129.339996  130.520004  128.729996  129.339996       129.339996
# 2022-05-12  129.160004  131.220001  128.550003  129.979996       129.979996
# 2022-05-13  130.529999  131.740005  130.300003  131.110001       131.110001
#
# [1098 rows x 5 columns]

# %% [markdown]
# > Cuando un DataFrame contiene más de 50 renglones, pandas despliega en automático los primeros y últimos 5 renglones e indica el tamaño de la tabla, en este caso 783 filas y 5 columnas

# %% [markdown]
# ### 2.1 Cargar multiples emisoras:  Arca, Femsa, AmericaMóvil

# %% [markdown]
# Podemos importar precios de diferentes emisoras a la vez, especificando una lista con los tikcers de interés.  Por default, al importar más de una acción, se baja el precio de cierre ajustado.

# %%
cierre_ajustado = db.Precios(['ac', 'femsaubd', 'amxl'], '2021-02-10','2022-05-16').resultado

# %% [markdown]
# > A diferencia de los precios de Arca, en este ejemplo los tickers están agrupados adentro de una lista delimitados por corchetes.  Python interpreta todo lo que esté entre corchetes como una lista de datos.

# %%
cierre_ajustado
# Out:
#                     AC    FEMSAUBD       AMXL
# Fecha
# 2021-02-10   87.160545  136.116165  13.479214
# 2021-02-11   86.686172  132.397522  13.235026
# 2021-02-12   86.593163  133.784775  13.528052
# 2021-02-15   87.588387  132.147049  13.606193
# 2021-02-16   88.592903  138.110367  13.625727
# ...                ...         ...        ...
# 2022-05-09  128.990005  141.149994  18.910000
# 2022-05-10  129.199997  141.690002  19.170000
# 2022-05-11  129.339996  142.820007  19.740000
# 2022-05-12  129.979996  147.000000  20.080000
# 2022-05-13  131.110001  148.509995  19.360001
#
# [318 rows x 3 columns]

# %% [markdown]
# ### 2.2 Descargar otros precios

# %% [markdown]
# Para descargar el precio `Apertura`, `Máximo`, `Mínimo` o `Cierre` hay que especificarlo en el parámetro `tipo_precio`.

# %%
precio_max = db.Precios(['ac', 'femsaubd', 'amxl'], '2021-02-10','2022-05-16', tipo_precio='Máximo').resultado

# %%
precio_max
# Out:
#                     AC    FEMSAUBD       AMXL
# Fecha
# 2021-02-10   95.519997  142.910004  14.330000
# 2021-02-11   94.690002  141.699997  13.830000
# 2021-02-12   93.959999  139.750000  13.900000
# 2021-02-15   94.430000  138.979996  14.000000
# 2021-02-16   95.830002  143.600006  14.080000
# ...                ...         ...        ...
# 2022-05-09  131.500000  141.929993  19.070000
# 2022-05-10  133.130005  143.220001  19.250000
# 2022-05-11  130.520004  144.600006  19.840000
# 2022-05-12  131.220001  147.500000  20.190001
# 2022-05-13  131.740005  148.970001  20.160000
#
# [318 rows x 3 columns]

# %%
precio_min = db.Precios(['ac', 'femsaubd', 'amxl'], '2021-02-10','2022-05-16', tipo_precio='Mínimo').resultado

# %%
precio_min
# Out:
#                     AC    FEMSAUBD       AMXL
# Fecha
# 2021-02-10   93.309998  139.850006  13.760000
# 2022-05-13 13:30:00  74.339996  74.500000  73.949997  74.220001

# %% [markdown]
# # 4.0 Estados Financieros

# %% [markdown]
# Para trabajar con los estados financieros, es necesario crear primero una instancia y darle cualquier nombre.  En este caso vamos a llamarla __*estados_financieros*__:

# %%
estados_financieros = db.Reportes()
# Out:
# Instancia lista
# Unidades:  Millones
# ATENCION: Las siguientes emisoras reportan sus resultados en USD:
# ['AUTLAN', 'CEMEX', 'GCC', 'GISSA', 'GMEXICO', 'GRUMA', 'IENOVA', 'ORBIA', 'PE&OLES', 'VESTA', 'VISTA', 'VITRO', 'VOLAR']

# %% [markdown]
# Ya con la instancia creada, ahora si podemos cargar los diferentes estados financieros de las emisoras de capitales de la BMV.

# %% [markdown]
# ## Balance General

# %% [markdown]
# Vamos a cargar los balances generales de Cemex, del 2017Q1 al 2020Q3.  Esto lo podemos hacer de dos maneras:
# 1. Escribir en una lista las fechas de los reportes trimestrales específicos
# 1. Crear un rango de trimestres especificando la fecha del trimestre inicial y la fecha final del trimestre del rango.  Es importante definir **_rango=True_** para indicarle a dabu que se trata de un rango de fechas

# %% [markdown]
# ### 1. Trimestres específicos

# %%
cemex_balance = estados_financieros.balance('cemex', ['2020-03-31', '2021-03-31','2022-03-31'])

# %%
cemex_balance
# Out:
#                                                     2020-03-31  2021-03-31  \
# Efectivo y equivalentes                               1386.580    1308.730
# Cuentas por cobrar                                    1794.740    2000.670
# Impuestos por recuperar                                  0.000       0.000
# Otros activos financieros                              265.348     168.809
# Inventarios                                            971.315    1073.810
# Activos biológicos                                       0.000       0.000
# Otros activos no financieros                             0.000       0.000
# Activos circulantes distintos de los activos no...    4417.980    4552.020
# Activos mantenidos para venta                          359.048     155.764
# Total de activos circulantes                          4777.030    4707.790
# Cuentas por cobrar no circulantes                      167.046     154.429
# Impuestos por recuperar no circulantes                   0.000       0.000
# Inventarios no circulantes                               0.000       0.000
# Activos biológicos no circulantes                        0.000       0.000
# Otros activos financieros no circulantes                63.308     106.100
# Inversiones registradas por método de participa...       0.000       0.000
# Inversiones en subsidiarias, negocios conjuntos...     478.123     490.470
# Propiedades, planta y equipo                          9845.410    9983.180
# Propiedades de inversión                                 0.000       0.000
# Activos por derechos de uso                           1225.650    1177.730
# Crédito mercantil                                     9432.190    8472.080
# Activos intangibles distintos al crédito mercantil    2002.170    1736.340
# Activos por impuestos diferidos                        607.015     734.248
# Otros activos no financieros no circulantes              0.000       0.000
# Total de activos no circulantes                      23820.900   22854.600
# TOTAL ACTIVOS                                        28597.900   27562.400
# Cuentas por pagar a corto plazo                       2205.380    2484.970
# Impuestos por pagar a corto plazo                      190.416     414.888
# Otros pasivos financieros a corto plazo               1151.770    1402.400
# Pasivos por arrendamientos a corto plazo               279.988     282.832
# Otros pasivos no financieros a corto plazo               0.000       0.000
# Provisiones por beneficios a los empleados a co...     262.868     340.327
# Otras provisiones a corto plazo                        476.897     486.647
# Total provisiones circulantes                          739.765     826.974
# Total de pasivos circulantes distintos de los p...    4567.320    5412.060
# Total de pasivos no circulantes                      11266.700
# TOTAL PASIVOS                                        16660.500
# Capital social                                         318.159
# Prima en emisión de acciones                          7491.940
# Acciones en tesorería                                    0.000
# Utilidades acumuladas                                 3585.510
# Otros resultados integrales acumulados               -1335.850
# Total de la participación controladora               10059.800
# Participación no controladora                          456.607
# TOTAL PASIVOS Y CAPITAL CONTABLE                     27176.900
# TOTAL CAPITAL CONTABLE                               10516.400

# %% [markdown]
# ### 2. Rango de fechas

# %%
cemex_balance = estados_financieros.balance('cemex', ['2020-01-01','2022-03-31'], rango = True)

# %% [markdown]
# > A La instancia *__estados_financieros__* le aplicamos el método *__balance__* para accesar a los balances generales de la empresa de interés en las fechas de interés

# %%
cemex_balance
# Out:
#                                                     2020-03-31  2020-06-30  \
# Efectivo y equivalentes                               1386.580    2831.770
# Cuentas por cobrar                                    1794.740    1763.250
# Impuestos por recuperar                                  0.000       0.000
# Otros activos financieros                              265.348     244.626
# Inventarios                                            971.315     929.020
# Activos biológicos                                       0.000       0.000
# Otros activos no financieros                             0.000       0.000
# Activos circulantes distintos de los activos no...    4417.980    5768.660
# Activos mantenidos para venta                          359.048     355.788
# Total de activos circulantes                          4777.030    6124.450
# Cuentas por cobrar no circulantes                      167.046     165.713
# Impuestos por recuperar no circulantes                   0.000       0.000
# Inventarios no circulantes                               0.000       0.000
# Activos biológicos no circulantes                        0.000       0.000
# Otros activos financieros no circulantes                63.308      56.235
# Inversiones registradas por método de participa...       0.000       0.000
# Inversiones en subsidiarias, negocios conjuntos...     478.123     469.483
# Propiedades, planta y equipo                          9845.410    9879.780
# Propiedades de inversión                                 0.000       0.000
# Activos por derechos de uso                           1225.650    1226.110
# Crédito mercantil                                     9432.190    9451.500
# Activos intangibles distintos al crédito mercantil    2002.170    1983.150
# Activos por impuestos diferidos                        607.015     603.401
# Otros activos no financieros no circulantes              0.000       0.000
# Total de activos no circulantes                      23820.900   23835.400
# TOTAL ACTIVOS                                        28597.900   29959.800
# Cuentas por pagar a corto plazo                       2205.380    2071.580
# Impuestos por pagar a corto plazo                      190.416     214.804
# Otros pasivos financieros a corto plazo               1151.770    1346.570
# Pasivos por arrendamientos a corto plazo               279.988     281.412
# Otros pasivos no financieros a corto plazo               0.000       0.000
# Provisiones por beneficios a los empleados a co...     262.868     266.492
# Otras provisiones a corto plazo                        476.897     461.460
# Total provisiones circulantes                          739.765     727.952
# Total de pasivos circulantes distintos de los p...    4567.320    4642.310
# Pasivos atribuibles a activos mantenidos para l...      22.074      20.240
# Total de pasivos circulantes                          4589.400    4662.560
# Cuentas por pagar largo plazo                            0.000       0.000
# Impuestos por pagar a largo plazo                        0.000       0.000
# Otros pasivos financieros a largo plazo              11120.800   12318.400
# Pasivos por arrendamientos a largo plazo               971.354     974.873
# Otros pasivos no financieros a largo plazo               0.000       0.000
# Provisiones por beneficios a los empleados a La...    1021.480    1031.940
# Otras provisiones a largo plazo                          0.000       0.000
# Total provisiones a largo plazo                       1021.480    1031.940
# Pasivo por impuestos diferidos                         720.211     754.701
# TOTAL CAPITAL CONTABLE                                9991.490   10271.100
#
#                                                     2022-03-31
# Efectivo y equivalentes                                592.863
# Cuentas por cobrar                                    2282.020
# Impuestos por recuperar                                  0.000
# Otros activos financieros                              231.954
# Inventarios                                           1393.340
# Activos biológicos                                       0.000
# Otros activos no financieros                             0.000
# Activos circulantes distintos de los activos no...    4500.170
# Activos mantenidos para venta                          146.674
# Total de activos circulantes                          4646.850
# Cuentas por cobrar no circulantes                      180.053
# Impuestos por recuperar no circulantes                   0.000
# Inventarios no circulantes                               0.000
# Activos biológicos no circulantes                        0.000
# Otros activos financieros no circulantes               127.288
# Inversiones registradas por método de participa...       0.000
# Inversiones en subsidiarias, negocios conjuntos...     543.936
# Propiedades, planta y equipo                         10228.300
# Propiedades de inversión                                 0.000
# Activos por derechos de uso                           1126.100
# Crédito mercantil                                     8004.870
# Activos intangibles distintos al crédito mercantil    1768.870
# Activos por impuestos diferidos                        550.653
# Otros activos no financieros no circulantes              0.000
# Total de activos no circulantes                      22530.000
# TOTAL ACTIVOS                                        27176.900
# Cuentas por pagar a corto plazo                       2771.330
# Impuestos por pagar a corto plazo                      398.903
# Otros pasivos financieros a corto plazo               1105.760
# Pasivos por arrendamientos a corto plazo               267.200
# Otros pasivos no financieros a corto plazo               0.000
# Provisiones por beneficios a los empleados a co...     352.645
# Otras provisiones a corto plazo                        455.845
# Total provisiones circulantes                          808.490
# Total de pasivos circulantes distintos de los p...    5351.680
# Pasivos atribuibles a activos mantenidos para l...      42.117
# Total de pasivos circulantes                          5393.800
# Cuentas por pagar largo plazo                            0.000
# Impuestos por pagar a largo plazo                        0.000
# Otros pasivos financieros a largo plazo               8900.630
# Pasivos por arrendamientos a largo plazo               923.072
# Otros pasivos no financieros a largo plazo               0.000
# Provisiones por beneficios a los empleados a La...     958.504
# Otras provisiones a largo plazo                          0.000
# Total provisiones a largo plazo                        958.504
# Pasivo por impuestos diferidos                         484.501
# Total de pasivos no circulantes                      11266.700
# TOTAL PASIVOS                                        16660.500
# Capital social                                         318.159
# Prima en emisión de acciones                          7491.940
# Acciones en tesorería                                    0.000
# Utilidades acumuladas                                 3585.510
# Otros resultados integrales acumulados               -1335.850
# Total de la participación controladora               10059.800
# Participación no controladora                          456.607
# TOTAL PASIVOS Y CAPITAL CONTABLE                     27176.900
# TOTAL CAPITAL CONTABLE                               10516.400

# %% [markdown]
# ## Estado de Resultados

# %% [markdown]
# De manera muy similar a la anterior, podemos importar el estado de resultados, aplicándo el método *__resultados__* al la instancia *__estados_financieros__*:

# %%
cemex_resultados = estados_financieros.resultados('cemex', ['2020-01-01','2022-03-31'], rango = True)

# %%
cemex_resultados
# Out:
#                                                     2020-03-31  2020-06-30  \
# Ingresos                                              3085.270    2911.550
# Costo de ventas                                       2119.720    1979.450
# Utilidad bruta                                         965.546     932.100
# Gasto de venta                                          86.258      82.149
# Gastos de administración                               618.856     571.198
# Otros ingresos                                           0.000       0.000
# Otros gastos                                            42.746      69.776
# Utilidad de operación                                  217.686     208.977
# Ingresos financieros                                    56.647      30.454
# Costos financieros                                     212.177     194.498
# Participación en la utilidad (pérdida) de asoci...       4.915       8.574
# Utilidad (pérdida) antes de impuestos                   67.071      53.507
# Impuestos a utilidad                                    50.027      39.817
# Utilidad neta de operaciones continuas                  17.044      13.690
# Utilidad neta de operaciones discontinuadas             30.188     -55.313
# UTILIDAD NETA CONSOLIDADA                               47.232     -41.623
# Participación controlada                                42.169     -43.705
# Participación no controlada                              5.063       2.082
#
#                                                     2020-09-30  2020-12-31  \
# Ingresos                                              3436.220    3537.460
# Costo de ventas                                       2260.030    2432.370
# Utilidad bruta                                        1176.180    1105.080
# Gasto de venta                                          78.491      89.843
# Gastos de administración                               645.007     663.816
# Otros ingresos                                           0.000       0.000
# Otros gastos                                          1635.690      30.647
# Utilidad de operación                                -1183.000     320.778
# Ingresos financieros                                     3.681       8.385
# Costos financieros                                     302.913     277.101
# Participación en la utilidad (pérdida) de asoci...      17.829      18.051
# Utilidad (pérdida) antes de impuestos                -1464.400      70.113
# Impuestos a utilidad                                   -19.351     -18.144
# Utilidad neta de operaciones continuas               -1445.050      88.257
# Utilidad neta de operaciones discontinuadas            -80.092     -15.051
# UTILIDAD NETA CONSOLIDADA                            -1525.140      73.206
# Participación controlada                             -1535.420      69.723
# Participación no controlada                             10.274       3.483
#
#                                                     2021-03-31  2021-06-30  \
# Ingresos                                              3411.030    3855.300
# Costo de ventas                                       2301.970    2554.650
# Utilidad bruta                                        1109.060    1300.650
# Gasto de venta                                          81.254      76.476
# Gastos de administración                               621.737     697.471
# Otros ingresos                                         569.797       0.000
# Otros gastos                                             0.000      24.630
# Utilidad de operación                                  975.865     502.074
# Ingresos financieros                                     3.229       6.258
# Costos financieros                                     267.264     187.075
# Participación en la utilidad (pérdida) de asoci...       3.345      15.469
# Utilidad (pérdida) antes de impuestos                  715.175     336.726
# Impuestos a utilidad                                    74.747      58.409
# Utilidad neta de operaciones continuas                 640.428     278.317
# Utilidad neta de operaciones discontinuadas             31.965       1.639
# UTILIDAD NETA CONSOLIDADA                              672.393     279.956
# Participación controlada                               664.532     269.941
# Participación no controlada                              7.861      10.015
#
#                                                     2021-09-30  2021-12-31  \
# Ingresos                                              3768.560    3618.230
# Costo de ventas                                       2550.030    2528.210
# Utilidad bruta                                        1218.520    1090.020
# Gasto de venta                                          84.840      83.310
# Gastos de administración                               670.717     640.484
# Otros ingresos                                           0.000       0.000
# Otros gastos                                           587.584      80.350
# Utilidad de operación                                 -124.619     285.878
# Ingresos financieros                                     3.575      10.424
# Costos financieros                                     151.278     154.379
# Participación en la utilidad (pérdida) de asoci...      18.956      16.153
# Utilidad (pérdida) antes de impuestos                 -253.366     158.076
# Impuestos a utilidad                                   100.523     -82.925
# Utilidad neta de operaciones continuas                -353.889     241.001
# Utilidad neta de operaciones discontinuadas            -24.078     -36.746
# UTILIDAD NETA CONSOLIDADA                             -377.967     204.255
# Participación controlada                              -376.165     194.806
# Participación no controlada                             -1.802       9.449
#
#                                                     2022-03-31
# Ingresos                                              3769.990
# Costo de ventas                                       2610.460
# Utilidad bruta                                        1159.530
# Gasto de venta                                          85.207
# Gastos de administración                               664.573
# Otros ingresos                                           0.000
# Otros gastos                                            21.167
# Utilidad de operación                                  388.582
# Ingresos financieros                                     3.896
# Costos financieros                                     147.270
# Participación en la utilidad (pérdida) de asoci...       5.401
# Utilidad (pérdida) antes de impuestos                  250.609
# Impuestos a utilidad                                    52.140
# Utilidad neta de operaciones continuas                 198.469
# Utilidad neta de operaciones discontinuadas              9.345
# UTILIDAD NETA CONSOLIDADA                              207.814
# Participación controlada                               198.085
# Participación no controlada                              9.729

# %% [markdown]
# ## Flujos de efectivo

# %% [markdown]
# Y para los flujos de efectivos solamente debemos de hacer lo siguiente:

# %%
cemex_flujos = estados_financieros.flujos('cemex', ['2020-01-01','2022-03-31'], rango = True)

# %%
cemex_flujos
# Out:
#                                                     2020-03-31  2020-06-30  \
# Impuestos a la utilidad                                 50.027      89.844
# Utilidad  de operaciones discontinuadas                 30.188     -25.125
# Utilidad neta                                           47.232       5.608
# Ingresos y gastos financieros, neto                      0.000       0.000
# Gastos de depreciación y amortización                  273.365     548.600
# ...                                                        ...         ...
# Impuestos a las ganancias reembolsados                   0.000       0.000
# FLUJOS DE EFECTIVO NETOS PROCEDENTES DE ACTIVID...     193.447    1374.290
# Incremento neto de efectivo y equivalentes, ant...     598.693    2043.870
# Efectos de la variación en la tasa de cambio so...       0.000       0.000
# INCREMENTO NETO DE EFECTIVO Y EQUIVALENTES             598.693    2043.870
#
#                                                     2020-09-30  2020-12-31  \
# Impuestos a la utilidad                                 70.492      52.349
# Utilidad  de operaciones discontinuadas               -105.217    -120.267
# Utilidad neta                                        -1519.530   -1446.330
# Ingresos y gastos financieros, neto                      0.000       0.000
# Gastos de depreciación y amortización                  824.171    1116.620
# ...                                                        ...         ...
# Impuestos a las ganancias reembolsados                   0.000       0.000
# FLUJOS DE EFECTIVO NETOS PROCEDENTES DE ACTIVID...    1176.530   -2069.770
# Incremento neto de efectivo y equivalentes, ant...    2665.290     162.475
# Efectos de la variación en la tasa de cambio so...       0.000       0.000
# INCREMENTO NETO DE EFECTIVO Y EQUIVALENTES            2665.290     162.475
#
#                                                     2021-03-31  2021-06-30  \
# Impuestos a la utilidad                                 74.747     133.156
# Utilidad  de operaciones discontinuadas                 31.965      33.604
# Utilidad neta                                          672.393     952.351
# Ingresos y gastos financieros, neto                      0.000       0.000
# Gastos de depreciación y amortización                  278.254     569.282
# ...                                                        ...         ...
# Impuestos a las ganancias reembolsados                   0.000       0.000
# FLUJOS DE EFECTIVO NETOS PROCEDENTES DE ACTIVID...    -986.378    -829.536
# Incremento neto de efectivo y equivalentes, ant...     358.367     354.291
# Efectos de la variación en la tasa de cambio so...       0.000       0.000
# INCREMENTO NETO DE EFECTIVO Y EQUIVALENTES             358.367     354.291
#
#                                                     2021-09-30  2021-12-31  \
# Impuestos a la utilidad                                233.679     143.225
# Utilidad  de operaciones discontinuadas                  9.525     -10.011
# Utilidad neta                                          574.382     778.462
# Ingresos y gastos financieros, neto                      0.000       0.000
# Gastos de depreciación y amortización                  845.979    1126.760
# ...                                                        ...         ...
# Impuestos a las ganancias reembolsados                   0.000       0.000
# FLUJOS DE EFECTIVO NETOS PROCEDENTES DE ACTIVID...   -1656.780   -2328.750
# Incremento neto de efectivo y equivalentes, ant...     -81.118    -337.546
# Efectos de la variación en la tasa de cambio so...       0.000       0.000
# INCREMENTO NETO DE EFECTIVO Y EQUIVALENTES             -81.118    -337.546
#
#                                                     2022-03-31
# Impuestos a la utilidad                                 52.140
# Utilidad  de operaciones discontinuadas                  9.345
# Utilidad neta                                          207.814
# Ingresos y gastos financieros, neto                      0.000
# Gastos de depreciación y amortización                  281.015
# ...                                                        ...
# Impuestos a las ganancias reembolsados                   0.000
# FLUJOS DE EFECTIVO NETOS PROCEDENTES DE ACTIVID...    -165.534
# Incremento neto de efectivo y equivalentes, ant...     -19.957
# Efectos de la variación en la tasa de cambio so...       0.000
# INCREMENTO NETO DE EFECTIVO Y EQUIVALENTES             -19.957
#
# [68 rows x 9 columns]

# %% [markdown]
# ## Comparar estado de resultados entre varias empresas

# %% [markdown]
# Podemos comparar varias emisoras en un mismo estado financiero utilizando la clase *__comparar__*.  En ella especificas el estado financiero a comparar, la fecha de comparación y una lista con las emisoras a comparar.
#
# Vamos ha hacer una comparativa del estado de resultados con cadenas de supermercados

# %%
supers_resultados = estados_financieros.comparar('resultados', '2022-03-31', ['CHDRAUI', 'SORIANA', 'WALMEX'])

# %%
supers_resultados
# Out:
#                                                       CHDRAUI    SORIANA  \
# Ingresos                                            60727.900  37408.300
# Costo de ventas                                     47073.600  29118.000
# Utilidad bruta                                      13654.300   8290.280
# Gasto de venta                                      10723.600   6322.040
# Gastos de administración                                0.000      0.000
# Otros ingresos                                         25.081    129.836
# Otros gastos                                          105.684     26.875
# Utilidad de operación                                2850.090   2071.210
# Ingresos financieros                                   66.005     61.629
# Costos financieros                                   1320.500    581.933
# Participación en la utilidad (pérdida) de asoci...     21.386    -64.978
# Utilidad (pérdida) antes de impuestos                1616.980   1485.920
# Impuestos a utilidad                                  522.294    548.666
# Utilidad neta de operaciones continuas               1094.690    937.258
# Utilidad neta de operaciones discontinuadas             0.000      0.000
# UTILIDAD NETA CONSOLIDADA                            1094.690    937.258
# Participación controlada                             1064.430    930.345
# Participación no controlada                            30.258      6.913
#
#                                                         WALMEX
# Ingresos                                            187844.000
# Costo de ventas                                     143855.000
# Utilidad bruta                                       43989.400
# Gasto de venta                                           0.000
# Gastos de administración                             28284.900
# Otros ingresos                                         326.279
# Otros gastos                                            93.588
# Utilidad de operación                                15937.200
# Ingresos financieros                                   434.389
# Costos financieros                                    2027.180
# Participación en la utilidad (pérdida) de asoci...       0.000
# Utilidad (pérdida) antes de impuestos                14344.400
# Impuestos a utilidad                                  3235.560
# Utilidad neta de operaciones continuas               11108.800
# Utilidad neta de operaciones discontinuadas              0.000
# UTILIDAD NETA CONSOLIDADA                            11108.800
# Participación controlada                             11108.800
# Participación no controlada                              0.000

# %% [markdown]
# Esto es solo el inicio, ya obtuvimos la información de una manera práctica y rápida.  Para calular retornos diarios, razones financieras, comparar empresas, trimestres, etc. puedes utilizar toda las funcionalidades de python y sus librerías como pandas, numpy, matplotlib.

# %% [markdown]
# ## Algunos comandos de la librería Pandas

# %% [markdown]
# ### Importar pandas

# %%
import pandas as pd

# %% [markdown]
# ### Calcular margen utilidad neta en el DataFrame super_resultados utilizando ".loc"

# %% [markdown]
# Para calcular el margen de utilidad seguimos la siguiente fórmula:
# $$MargenUtilidad = \frac{UtilidadNeta}{Ingresos}$$
# <br>
# El atributo `.loc` de pandas te permite seleccionar todos los valores de una fila o index.  Para nuesto caso vamos a seleccionar el index `'UTILIDAD NETA CONSOLIDADA'` y dividirlo entre el index `'Ingresos'`.  El resultado lo guardaremos en la variable *__utilidad_neta__*

# %%
utilidad_neta = supers_resultados.loc['UTILIDAD NETA CONSOLIDADA'] / supers_resultados.loc['Ingresos']

# %%
utilidad_neta
# Out:
# CHDRAUI    0.018026
# SORIANA    0.025055
# WALMEX     0.059138
# dtype: float64

# %% [markdown]
# Para accesar el valor de Walmex lo hacemos de la siguiente manera:

# %%
utilidad_neta['WALMEX']
# Out:
# 0.05913843401971849

# %% [markdown]
# ### Guardar el comparativo supermercados a un archivo de Excel:

# %% [markdown]
# Es muy fácil guardar un DataFrame en un archivo de excel.  Vamos a guardar el comparativo de los supermercados en un archivo de excel que llamaremos 'supermercados.xlsx' y a la hoja le llamaremos 'Estado de Resultados'.

# %%
supers_resultados.to_excel('supermercados.xlsx', sheet_name = 'Estado de Resultados')

# %% [markdown]
# Pandas guarda el archivo de excel en la misma ubicación de donde se encuentra la libreta.

# %% [markdown]
# ### Guardar el balance general, estado de resultados, flujos de efectivo de Cemex a un archivo de Excel

# %% [markdown]
# También podemos guardar varios DataFrames en un mismo archivo.  En este ejemplo vamos a guardar los tres estados financieros de Cemex en un solo archivo de excel.  La manera de hacerlo es diferente pero fácil:

# %%
with pd.ExcelWriter('cemex.xlsx') as writer:  
    cemex_balance.to_excel(writer, sheet_name='Balance General')
    cemex_resultados.to_excel(writer, sheet_name='Estado de Resultados')
    cemex_flujos.to_excel(writer, sheet_name='Estado de Flujos Efectivos')

# %% [markdown]
# ### Graficar dataframes

# %% [markdown]
# Podemos hacer gráficas muy sencillas

# %%
ac['Cierre'].plot();

# %% [markdown]
# O un poco más complejas con poca programación:

# %%
ac['Cierre'].plot(figsize=(12,8), title='Precios cierre Arca', xlabel='Fecha', ylabel='MXN',grid=True, color='red');

# %% [markdown]
# Consulta el código de la librería en https://github.com/dabu-io/dabu-dev<br>
# Encontraste un bug en el código? Tienes una sugerencia? Ingrésala en https://github.com/dabu-io/dabu-dev/issues/new<br>
# Visita www.dabu.digital<br>
# Carlos Crespo, carlos@dabu.digital, @dabu_io<br>
# _Última actualización 2022-05-16_
